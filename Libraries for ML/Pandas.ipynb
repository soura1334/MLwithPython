# %% [markdown]
# <a href="https://colab.research.google.com/github/soura1334/PyMLLibs/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas DataFrame - 2 dimensional tabular data structure with labeled axes

# %% [markdown]
# Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a Pandas DataFrame

# %% [markdown]
# Importing the Boston house price data

# %%
from sklearn.datasets import fetch_california_housing

# %%
cali_dataset = fetch_california_housing()

# %%
type(cali_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(cali_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %% [markdown]
# Pandas DataFrame

# %%
cali_df = pd.DataFrame(cali_dataset.data, columns = cali_dataset.feature_names)

# %%
cali_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]

# %%
cali_df.shape
# Out:
# (20640, 8)

# %%
type(cali_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Importing the data from a CSV file to a Pandas DataFrame

# %%
diabetes_df = pd.read_csv("/content/diabetes.csv")

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# # Loading Data from an Excel File to DataFrame
# pd.read_excel("file path")

# %% [markdown]
# # Exporting a DataFrame to a CSV file

# %%
cali_df.to_csv("cali.csv")

# %% [markdown]
# # Exporting a DataFrame to an Excel file

# %%
cali_df.to_excel("cali.xlsx")

# %% [markdown]
# # Creating a DataFrame with random values

# %%
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2  ...         7         8         9
# 0  0.095037  0.053095  0.291284  ...  0.881113  0.014445  0.621314
# 1  0.474904  0.892541  0.357625  ...  0.434464  0.555973  0.940845
# 2  0.314117  0.338377  0.413760  ...  0.002003  0.602363  0.218372
# 3  0.503219  0.601317  0.406670  ...  0.423343  0.056012  0.985406
# 4  0.384922  0.532936  0.405433  ...  0.125903  0.554419  0.287012
#
# [5 rows x 10 columns]

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# # Inspecting a DataFrame

# %% [markdown]
# Finding number of rows and columns

# %%
cali_df.shape
# Out:
# (20640, 8)

# %% [markdown]
# First 5 rows in a DataFrame

# %%
cali_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]

# %% [markdown]
# Last 5 rows in a DataFrame

# %%
cali_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 20635  1.5603      25.0  5.045455  ...  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035  ...  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543  ...  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513  ...  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717  ...  2.616981     39.37    -121.24
#
# [5 rows x 8 columns]

# %% [markdown]
# Information about the DataFrame

# %%
cali_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %% [markdown]
# Finding the number of missing values

# %%
cali_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %% [markdown]
# Diabetes DF

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# Counting the values based on the labels

# %%
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# Group the values based on the mean

# %%
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %% [markdown]
# # Statistical Measures

# %% [markdown]
# Count or number of values

# %%
cali_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %% [markdown]
# Mean value- column wise

# %%
cali_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %% [markdown]
# Standard Deviation

# %%
cali_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %% [markdown]
# Minimum Value

# %%
cali_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %% [markdown]
# Maximum Value

# %%
cali_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %% [markdown]
# All the statistical measures about the DataFrame

# %%
cali_df.describe()
# Out:
#              MedInc      HouseAge  ...      Latitude     Longitude
# count  20640.000000  20640.000000  ...  20640.000000  20640.000000
# mean       3.870671     28.639486  ...     35.631861   -119.569704
# std        1.899822     12.585558  ...      2.135952      2.003532
# min        0.499900      1.000000  ...     32.540000   -124.350000
# 25%        2.563400     18.000000  ...     33.930000   -121.800000
# 50%        3.534800     29.000000  ...     34.260000   -118.490000
# 75%        4.743250     37.000000  ...     37.710000   -118.010000
# max       15.000100     52.000000  ...     41.950000   -114.310000
#
# [8 rows x 8 columns]

# %% [markdown]
# # Manipulating a DataFrame

# %% [markdown]
# Adding a Column

# %%
cali_df['Price'] = cali_dataset.target

# %%
cali_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  Price
# 0  8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23  4.526
# 1  8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22  3.585
# 2  7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24  3.521
# 3  5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25  3.413
# 4  3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25  3.422
#
# [5 rows x 9 columns]

# %% [markdown]
# Removing a Row

# %%
cali_df.drop(index=0, axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  Price
# 1      8.3014      21.0  6.238137  ...     37.86    -122.22  3.585
# 2      7.2574      52.0  8.288136  ...     37.85    -122.24  3.521
# 3      5.6431      52.0  5.817352  ...     37.85    -122.25  3.413
# 4      3.8462      52.0  6.281853  ...     37.85    -122.25  3.422
# 5      4.0368      52.0  4.761658  ...     37.85    -122.25  2.697
# ...       ...       ...       ...  ...       ...        ...    ...
# 20635  1.5603      25.0  5.045455  ...     39.48    -121.09  0.781
# 20636  2.5568      18.0  6.114035  ...     39.49    -121.21  0.771
# 20637  1.7000      17.0  5.205543  ...     39.43    -121.22  0.923
# 20638  1.8672      18.0  5.329513  ...     39.43    -121.32  0.847
# 20639  2.3886      16.0  5.254717  ...     39.37    -121.24  0.894
#
# [20639 rows x 9 columns]

# %% [markdown]
# Removing a Column

# %%
cali_df.drop(columns='MedInc', axis = 1)
# Out:
#        HouseAge  AveRooms  AveBedrms  ...  Latitude  Longitude  Price
# 0          41.0  6.984127   1.023810  ...     37.88    -122.23  4.526
# 1          21.0  6.238137   0.971880  ...     37.86    -122.22  3.585
# 2          52.0  8.288136   1.073446  ...     37.85    -122.24  3.521
# 3          52.0  5.817352   1.073059  ...     37.85    -122.25  3.413
# 4          52.0  6.281853   1.081081  ...     37.85    -122.25  3.422
# ...         ...       ...        ...  ...       ...        ...    ...
# 20635      25.0  5.045455   1.133333  ...     39.48    -121.09  0.781
# 20636      18.0  6.114035   1.315789  ...     39.49    -121.21  0.771
# 20637      17.0  5.205543   1.120092  ...     39.43    -121.22  0.923
# 20638      18.0  5.329513   1.171920  ...     39.43    -121.32  0.847
# 20639      16.0  5.254717   1.162264  ...     39.37    -121.24  0.894
#
# [20640 rows x 8 columns]

# %% [markdown]
# Locating a row using the index value

# %%
cali_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %% [markdown]
# Locating a particular column

# %%
cali_df.iloc[:,0] # first column
cali_df.iloc[:,1] # second column
cali_df.iloc[:,2] # third column
cali_df.iloc[:,-1] # last column
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %% [markdown]
# # Correlation
#
# *   Positive Correlation
# *   Negative Correlation

# %%
cali_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  ...  Latitude  Longitude     Price
# MedInc      1.000000 -0.119034  0.326895  ... -0.079809  -0.015176  0.688075
# HouseAge   -0.119034  1.000000 -0.153277  ...  0.011173  -0.108197  0.105623
# AveRooms    0.326895 -0.153277  1.000000  ...  0.106389  -0.027540  0.151948
# AveBedrms  -0.062040 -0.077747  0.847621  ...  0.069721   0.013344 -0.046701
# Population  0.004834 -0.296244 -0.072213  ... -0.108785   0.099773 -0.024650
# AveOccup    0.018766  0.013191 -0.004852  ...  0.002366   0.002476 -0.023737
# Latitude   -0.079809  0.011173  0.106389  ...  1.000000  -0.924664 -0.144160
# Longitude  -0.015176 -0.108197 -0.027540  ... -0.924664   1.000000 -0.045967
# Price       0.688075  0.105623  0.151948  ... -0.144160  -0.045967  1.000000
#
# [9 rows x 9 columns]
